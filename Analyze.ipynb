# %% [markdown]
# Outputs a summary of each variable to a single
# The iris dataset is a classic and very easy multi-class classification dataset.
#
# Classs
#  # Iris Setosa: # Iris Versicolour: # Iris Virginica:
#
# 3
#
# Samples perclass
#
# 50
#
# Samles
# otal
#
# 150
#
# im # sepal length   # sepal width  # petal length # petal width es
#
# real, positive

# %%
# import the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      rownumber  sepal_length  sepal_width  petal_length  petal_width  \
# 0            1           5.1          3.5           1.4          0.2
# 1            2           4.9          3.0           1.4          0.2
# 2            3           4.7          3.2           1.3          0.2
# 3            4           4.6          3.1           1.5          0.2
# 4            5           5.0          3.6           1.4          0.2
# ..         ...           ...          ...           ...          ...
# 145        146           6.7          3.0           5.2          2.3
# 146        147           6.3          2.5           5.0          1.9
# 147        148           6.5          3.0           5.2          2.0
# 148        149           6.2          3.4           5.4          2.3
# 149        150           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...

# %%
# The code below shows  the lines in my df
pd.set_option('display.max_rows',None)

# %%
iris
# Out:
#      rownumber  sepal_length  sepal_width  petal_length  petal_width  \
# 0            1           5.1          3.5           1.4          0.2
# 1            2           4.9          3.0           1.4          0.2
# 2            3           4.7          3.2           1.3          0.2
# 3            4           4.6          3.1           1.5          0.2
# 4            5           5.0          3.6           1.4          0.2
# 5            6           5.4          3.9           1.7          0.4
# 6            7           4.6          3.4           1.4          0.3
# 7            8           5.0          3.4           1.5          0.2
# 8            9           4.4          2.9           1.4          0.2
# 9           10           4.9          3.1           1.5          0.1
# 10          11           5.4          3.7           1.5          0.2
# 11          12           4.8          3.4           1.6          0.2
# 12          13           4.8          3.0           1.4          0.1
# ...

# %%
iris = pd.read_csv('iris.csv')

# %%
# The dtype command shows the type of each variable (numeric, float, object, etc.)
iris.dtypes
# Out:
# rownumber         int64
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# In this code I am requesting that my database only shows  lines with the species setosa
iris_filtrado = iris[iris['species'] == 'setosa']

# %%
# With the drop command I am requesting that a column (number of rows) that is repeated be deleted from my df
iris_filtrado = iris_filtrado.drop('rownumber', axis=1)
print(iris_filtrado)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
# And finally creating my histogram based on the df edited in the lines above

import pandas as pd
import matplotlib.pyplot as plt
iris_filtrado.hist(bins=5, figsize=(50, 50), layout=(5, 5), edgecolor='black')
plt.suptitle('Histogram of Setosa species variables')
# plt.show()
plt.savefig('figura_setosa.png')

# %%
# In this code I am requesting that my database only shows  lines with the species versicolor
iris_filtrado = iris[iris['species'] == 'versicolor']

# %%
iris_filtrado = iris_filtrado.drop('rownumber', axis=1)
print(iris_filtrado)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
iris_filtrado.hist(bins=5, figsize=(50, 50), layout=(5, 5), edgecolor='black')
plt.suptitle('Histogram of Versicolor species variables')
# plt.show()
plt.savefig('figura_versicolor.png')

# %%
# In this code I am requesting that my database only shows  lines with the species virginica
iris_filtrado = iris[iris['species'] == 'virginica']

# %%
iris_filtrado = iris_filtrado.drop('rownumber', axis=1)
print(iris_filtrado)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
iris_filtrado.hist(bins=5, figsize=(50, 50), layout=(5, 5), edgecolor='black')
plt.suptitle('Histogram of Virginica species variables')
# plt.show()
plt.savefig('figura_virginica.png')

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      rownumber  sepal_length  sepal_width  petal_length  petal_width  \
# 0            1           5.1          3.5           1.4          0.2
# 1            2           4.9          3.0           1.4          0.2
# 2            3           4.7          3.2           1.3          0.2
# 3            4           4.6          3.1           1.5          0.2
# 4            5           5.0          3.6           1.4          0.2
# 5            6           5.4          3.9           1.7          0.4
# 6            7           4.6          3.4           1.4          0.3
# 7            8           5.0          3.4           1.5          0.2
# 8            9           4.4          2.9           1.4          0.2
# 9           10           4.9          3.1           1.5          0.1
# 10          11           5.4          3.7           1.5          0.2
# 11          12           4.8          3.4           1.6          0.2
# 12          13           4.8          3.0           1.4          0.1
# ...

# %%
iris['species'] = iris['species'].replace('setosa', '01')
iris
# Out:
#      rownumber  sepal_length  sepal_width  petal_length  petal_width  \
# 0            1           5.1          3.5           1.4          0.2
# 1            2           4.9          3.0           1.4          0.2
# 2            3           4.7          3.2           1.3          0.2
# 3            4           4.6          3.1           1.5          0.2
# 4            5           5.0          3.6           1.4          0.2
# 5            6           5.4          3.9           1.7          0.4
# 6            7           4.6          3.4           1.4          0.3
# 7            8           5.0          3.4           1.5          0.2
# 8            9           4.4          2.9           1.4          0.2
# 9           10           4.9          3.1           1.5          0.1
# 10          11           5.4          3.7           1.5          0.2
# 11          12           4.8          3.4           1.6          0.2
# 12          13           4.8          3.0           1.4          0.1
# ...

# %%
iris['species'] = iris['species'].replace('versicolor', '02')
iris
# Out:
#      rownumber  sepal_length  sepal_width  petal_length  petal_width  \
# 0            1           5.1          3.5           1.4          0.2
# 1            2           4.9          3.0           1.4          0.2
# 2            3           4.7          3.2           1.3          0.2
# 3            4           4.6          3.1           1.5          0.2
# 4            5           5.0          3.6           1.4          0.2
# 5            6           5.4          3.9           1.7          0.4
# 6            7           4.6          3.4           1.4          0.3
# 7            8           5.0          3.4           1.5          0.2
# 8            9           4.4          2.9           1.4          0.2
# 9           10           4.9          3.1           1.5          0.1
# 10          11           5.4          3.7           1.5          0.2
# 11          12           4.8          3.4           1.6          0.2
# 12          13           4.8          3.0           1.4          0.1
# ...

# %%
iris['species'] = iris['species'].replace('virginica', '03')
iris
# Out:
#      rownumber  sepal_length  sepal_width  petal_length  petal_width species
# 0            1           5.1          3.5           1.4          0.2      01
# 1            2           4.9          3.0           1.4          0.2      01
# 2            3           4.7          3.2           1.3          0.2      01
# 3            4           4.6          3.1           1.5          0.2      01
# 4            5           5.0          3.6           1.4          0.2      01
# 5            6           5.4          3.9           1.7          0.4      01
# 6            7           4.6          3.4           1.4          0.3      01
# 7            8           5.0          3.4           1.5          0.2      01
# 8            9           4.4          2.9           1.4          0.2      01
# 9           10           4.9          3.1           1.5          0.1      01
# 10          11           5.4          3.7           1.5          0.2      01
# ...

# %%
# Changing the data type (object to float) of the species column to plot the data
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rownumber     150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris['species']= iris['species'].astype('float')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rownumber     150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   species       150 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 7.2 KB

# %%
scatter= iris.plot.scatter(x = 'sepal_length', y='sepal_width' )

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Carregar o dataset Iris e criar um DataFrame
data = load_iris()
iris = pd.DataFrame(data.data, columns=data.feature_names)

# Criar uma função para mapear os valores de x e y para diferentes cores
def color_points(row):
    if row['sepal length (cm)'] > 5 and row['sepal width (cm)'] > 3:
        return 'red'
    elif row['sepal length (cm)'] <= 5 and row['sepal width (cm)'] > 3:
        return 'blue'
    elif row['sepal length (cm)'] > 5 and row['sepal width (cm)'] <= 3:
        return 'green'
    else:
        return 'purple'

# Aplicar a função ao DataFrame para criar uma nova coluna de cores
iris['color'] = iris.apply(color_points, axis=1)

# Criar o gráfico de dispersão com cores diferentes para cada ponto
scatter = iris.plot.scatter(x='sepal length (cm)', y='sepal width (cm)', c=iris['color'], edgecolor='black')

# Add title and labels to axes
scatter.set_title('Scatter Plot ', fontsize=14)
scatter.set_xlabel('Sepal Length (cm)', fontsize=12)
scatter.set_ylabel('Sepal Width (cm)', fontsize=12)

plt.show()

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset and create a DataFrame
data = load_iris()
iris = pd.DataFrame(data.data, columns=data.feature_names)

# Calculate the correlation matrix
correlation_matrix = iris.corr()

# Create the correlation graph (heatmap)
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title('Correlation Matrix ', fontsize=14)

plt.show()
